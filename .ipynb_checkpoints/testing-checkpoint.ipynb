# %%
# Import modules
from dask.distributed import Client, SSHCluster, progress
import dask.array as da

# %%
# Launch cluster
#cluster = SSHCluster(["-J faquista@gate.cloudveneto.it ubuntu@10.67.22.240", 
#                     "-J faquista@gate.cloudveneto.it ubuntu@10.67.22.240"], 
#                    connect_options={"username": "faquista", 
#                                     "password": "^WlFK*olXjW0^*15", 
#                                     "known_hosts": None, 
#                                     "agent_forwarding": True})

client = Client("tcp://localhost:8786")
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/parallel-processing/env/lib/python3.13/site-packages/tornado/iostream.py:861, in BaseIOStream._read_to_buffer(self)
#     860         buf = bytearray(self.read_chunk_size)
# --> 861     bytes_read = self.read_from_fd(buf)
#     862 except OSError as e:
#     863     # ssl.SSLError is a subclass of socket.error
#
# File ~/parallel-processing/env/lib/python3.13/site-packages/tornado/iostream.py:1113, in IOStream.read_from_fd(***failed resolving arguments***)
#    1112 try:
# -> 1113     return self.socket.recv_into(buf, len(buf))
#    1114 except BlockingIOError:
#
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# CommClosedError                           Traceback (most recent call last)
# Cell In[10], line 9
#       1 # Launch cluster
#       2 #cluster = SSHCluster(["-J faquista@gate.cloudveneto.it ubuntu@10.67.22.240",
#       3 #                     "-J faquista@gate.cloudveneto.it ubuntu@10.67.22.240"],
#    (...)      6 #                                     "known_hosts": None,
#       7 #                                     "agent_forwarding": True})
# ----> 9 client = Client("tcp://localhost:8786")
#
# File ~/parallel-processing/env/lib/python3.13/site-packages/distributed/client.py:1203, in Client.__init__(self, address, loop, timeout, set_as_default, scheduler_file, security, asynchronous, name, heartbeat_interval, serializers, deserializers, extensions, direct_to_workers, connection_limit, **kwargs)
#    1200 preload_argv = dask.config.get("distributed.client.preload-argv")
#    1201 self.preloads = preloading.process_preloads(self, preload, preload_argv)
# -> 1203 self.start(timeout=timeout)
#    1204 Client._instances.add(self)
#    1206 from distributed.recreate_tasks import ReplayTaskClient
#
# File ~/parallel-processing/env/lib/python3.13/site-packages/distributed/client.py:1403, in Client.start(self, **kwargs)
#    1401     self._started = asyncio.ensure_future(self._start(**kwargs))
#    1402 else:
# -> 1403     sync(self.loop, self._start, **kwargs)
#
# File ~/parallel-processing/env/lib/python3.13/site-packages/distributed/utils.py:452, in sync(loop, func, callback_timeout, *args, **kwargs)
#     449         wait(10)
#     451 if error is not None:
# --> 452     raise error
#     453 else:
#     454     return result
#
# File ~/parallel-processing/env/lib/python3.13/site-packages/distributed/utils.py:426, in sync.<locals>.f()
#     424         awaitable = wait_for(awaitable, timeout)
#     425     future = asyncio.ensure_future(awaitable)
# --> 426     result = yield future
#     427 except Exception as exception:
#     428     error = exception
#
# File ~/parallel-processing/env/lib/python3.13/site-packages/tornado/gen.py:769, in Runner.run(self)
#     767 try:
#     768     try:
# --> 769         value = future.result()
#     770     except Exception as e:
#     771         # Save the exception for later. It's important that
#     772         # gen.throw() not be called inside this try/except block
#     773         # because that makes sys.exc_info behave unexpectedly.
#     774         exc: Optional[Exception] = e
#
# File ~/parallel-processing/env/lib/python3.13/site-packages/distributed/client.py:1481, in Client._start(self, timeout, **kwargs)
#    1478 self.scheduler_comm = None
#    1480 try:
# -> 1481     await self._ensure_connected(timeout=timeout)
#    1482 except (OSError, ImportError):
#    1483     await self._close()
#
# File ~/parallel-processing/env/lib/python3.13/site-packages/distributed/client.py:1549, in Client._ensure_connected(self, timeout)
#    1546 self._connecting_to_scheduler = True
#    1548 try:
# -> 1549     comm = await connect(
#    1550         self.scheduler.address, timeout=timeout, **self.connection_args
#    1551     )
#    1552     comm.name = "Client->Scheduler"
#    1553     if timeout is not None:
#
# File ~/parallel-processing/env/lib/python3.13/site-packages/distributed/comm/core.py:377, in connect(addr, timeout, deserialize, handshake_overrides, **connection_args)
#     372 local_info = {
#     373     **comm.handshake_info(),
#     374     **(handshake_overrides or {}),
#     375 }
#     376 await comm.write(local_info)
# --> 377 handshake = await comm.read()
#     379 comm.remote_info = handshake
#     380 comm.remote_info["address"] = comm._peer_addr
#
# File ~/parallel-processing/env/lib/python3.13/site-packages/distributed/comm/tcp.py:237, in TCP.read(self, deserializers)
#     235     self.stream = None
#     236     self._closed = True
# --> 237     convert_stream_closed_error(self, e)
#     238 except BaseException:
#     239     # Some OSError, CancelledError or another "low-level" exception.
#     240     # We do not really know what was already read from the underlying
#     241     # socket, so it is not even safe to retry here using the same stream.
#     242     # The only safe thing to do is to abort.
#     243     # (See also GitHub #4133, #6548).
#     244     self.abort()
#
# File ~/parallel-processing/env/lib/python3.13/site-packages/distributed/comm/tcp.py:143, in convert_stream_closed_error(obj, exc)
#     141     if exc.reason and "UNKNOWN_CA" in exc.reason:
#     142         raise FatalCommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}")
# --> 143 raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
#
# CommClosedError: in <TCP (closed)  local=tcp://[::1]:65396 remote=tcp://localhost:8786>: ConnectionResetError: [Errno 54] Connection reset by peer

# %%
client
# Out:
# <Client: 'inproc://192.168.1.54/74444/1' processes=1 threads=4, memory=1.86 GiB>

# %%
# Close client
client.close()
